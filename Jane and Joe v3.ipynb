# %% [markdown]
# Person object parameters:
#
# Joe:
# has a state: Susceptible, Infected, Recovered
# has a number of days sick
# has a chance of being sick

# %%
import random
import numpy as np

# %%
class Person(object):
    def __init__(self):
        self.status = "Susceptible"
        self.days_sick = 0
        self.sickness_rate = 10
    
    def set_sickness_rate(self, new_sickness_rate):
        self.sickness_rate = new_sickness_rate
    
    def infect(self, number_of_days_sick):
        self.status = "Infected"
        self.days_sick = number_of_days_sick
        
    def recover(self):
        self.status = "Recovered"
        #self.days_sick = 0
    
    def update(self):
        if(self.status == "Susceptible"):
            self.roll_for_infection()
            
        elif(self.status == "Infected"):
            if(self.days_sick <= 0):
                self.recover()
            self.days_sick = self.days_sick - 1
            
    def roll_for_infection(self):
        is_sick = (random.randint(0,101) < self.sickness_rate)
        if(is_sick == True):
            self.infect(4)

# %%
Joe = Person()
Jane = Person()
Jane.set_sickness_rate(20)
day = 0
while(Joe.status != "Recovered" or Jane.status != "Recovered"):
    day += 1
    Joe.update() #update the status of Joe, and if joe is susceptible,
    #roll for infection and if it is a viable roll, infect Joe with the infect method
    #
    #
    if(Joe.status == "Infected" or Jane.status == "Infected"):
        Jane.update() #once joe is infected, then you can begin infecting jane
    
    print("Joe is " + Joe.status + " day:" + str(day))
    print("Jane is " + Jane.status + " day:" + str(day))
    
    #My conditions didn't happen let's rerun
    #if Joe is recovered and Jane is still susceptible, the conditions for our program weren't met
    #run it again!
    
    if(Joe.status == "Recovered" and Jane.status == "Susceptible"):
        Joe.status  = "Susceptible"
        day = 0
        print(" ---------------reset--------------- ")
# Out:
# Joe is Susceptible day:1
# Jane is Susceptible day:1
# Joe is Susceptible day:2
# Jane is Susceptible day:2
# Joe is Susceptible day:3
# Jane is Susceptible day:3
# Joe is Susceptible day:4
# Jane is Susceptible day:4
# Joe is Susceptible day:5
# Jane is Susceptible day:5
# Joe is Susceptible day:6
# Jane is Susceptible day:6
# Joe is Susceptible day:7
# Jane is Susceptible day:7
# Joe is Susceptible day:8
# Jane is Susceptible day:8
# Joe is Susceptible day:9
# Jane is Susceptible day:9
# Joe is Susceptible day:10
# Jane is Susceptible day:10
# Joe is Susceptible day:11
# Jane is Susceptible day:11
# Joe is Susceptible day:12
# Jane is Susceptible day:12
# Joe is Infected day:13
# Jane is Susceptible day:13
# Joe is Infected day:14
# Jane is Susceptible day:14
# Joe is Infected day:15
# Jane is Susceptible day:15
# Joe is Infected day:16
# Jane is Infected day:16
# Joe is Infected day:17
# Jane is Infected day:17
# Joe is Recovered day:18
# Jane is Infected day:18
# ...

# %%
my_population = [] #create an array 
my_populations_connections = []
np_interactions = np.zeros(shape = (100,10))

for i in range(0,100): #100 rows
    generic_dude = Person() #create 100 people
    my_population.append(generic_dude)
    for y in range(0,10): #10 columns
        generic_dude = Person() #create 10 people 
        my_populations_connections.append(generic_dude)
        person_interacted_with = random.randint(0,100)
        while person_interacted_with == i:
            person_interacted_with = random.randint(0,100)
        np_interactions[i,y] = person_interacted_with
    print("Person " + str(i) + " interacted with people: " + str(np_interactions[i, :]))
# Out:
# Person 0 interacted with people: [87. 49. 52. 13. 56. 15. 39. 82. 12. 52.]
# Person 1 interacted with people: [61. 77. 80. 39. 30. 12. 17. 67. 80.  0.]
# Person 2 interacted with people: [96. 46. 18. 75. 43. 64. 99. 87. 79. 42.]
# Person 3 interacted with people: [38. 29. 71. 42. 88. 46. 95.  2. 10.  6.]
# Person 4 interacted with people: [32.  6. 35. 24. 41. 31. 70. 40. 11. 13.]
# Person 5 interacted with people: [91. 12. 38. 14.  7.  9. 30.  8.  3. 78.]
# Person 6 interacted with people: [41. 17. 93. 90. 41. 66. 80. 55. 77. 33.]
# Person 7 interacted with people: [80. 71. 17. 73. 24. 68. 57. 54. 91. 25.]
# Person 8 interacted with people: [43. 72. 90. 68. 52. 62. 28. 66. 85. 88.]
# Person 9 interacted with people: [ 6. 98. 94. 83. 71.  3. 96. 69. 32. 93.]
# Person 10 interacted with people: [ 29.  91.   2.  31.  56.  90. 100.  88.  53.  43.]
# Person 11 interacted with people: [ 4. 45. 32. 23. 38. 68. 58. 54. 66. 28.]
# ...

# %%
infected_originally_list_of_names = []
infected_originally_list_of_indices = []
for x in range(0,10):
    z = random.randint(0,99)
    infected_originally = my_population[z]
    infected_originally.infect(5)
    infected_originally_list_of_names.append(infected_originally)
    infected_originally_list_of_indices.append(z)
    my_populations_connections[int(np_interactions[z,x])].update()
    print(int(np_interactions[z,x]))

print(len(infected_originally_list_of_names), "people are infected originally at the end of day one.")
    #my_populations_connections[np_interactions[z,:]].roll_for_infection()
# Out:
# 18
# 33
# 17
# 74
# 4
# 19
# 31
# 67
# 79
# 6
# 10 people are infected originally at the end of day one.
